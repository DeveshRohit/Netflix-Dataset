# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('netflix_titles.csv')
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# df.describe(include='all')

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df['show_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.iloc[:, :-1]

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df['country'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\DEVESH ROHIT\AppData\Local\Temp\ipykernel_15268\2372192134.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna('Unknown', inplace=True)

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df['director'].fillna('No director Listed', inplace=True)
# Out:
# C:\Users\DEVESH ROHIT\AppData\Local\Temp\ipykernel_15268\378719701.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['director'].fillna('No director Listed', inplace=True)

# %%
df
# Out:
#      show_id     type                  title            director  \
# 0         s1    Movie   Dick Johnson Is Dead     Kirsten Johnson
# 1         s2  TV Show          Blood & Water  No director Listed
# 2         s3  TV Show              Ganglands     Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans  No director Listed
# 4         s5  TV Show           Kota Factory  No director Listed
# ...      ...      ...                    ...                 ...
# 8802   s8803    Movie                 Zodiac       David Fincher
# 8803   s8804  TV Show            Zombie Dumb  No director Listed
# 8804   s8805    Movie             Zombieland     Ruben Fleischer
# 8805   s8806    Movie                   Zoom        Peter Hewitt
# 8806   s8807    Movie                 Zubaan         Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df['duration_minutes'] = df['duration'].str.extract(r"(\d+)\s*min").astype(float)
df['seasons'] = df['duration'].str.extract(r"(\d+)\s*Season").astype(float)

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead     Kirsten Johnson
# 1      s2  TV Show          Blood & Water  No director Listed
# 2      s3  TV Show              Ganglands     Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  No director Listed
# 4      s5  TV Show           Kota Factory  No director Listed
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                                NaN        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
def recent(year):
    if(year>=2015):
        return 1
    else:
        return 0

# %%
df['is_recent'] = df['release_year'].apply(recent)

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead     Kirsten Johnson
# 1      s2  TV Show          Blood & Water  No director Listed
# 2      s3  TV Show              Ganglands     Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  No director Listed
# 4      s5  TV Show           Kota Factory  No director Listed
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                                NaN        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
sns.countplot(x='type', data=df)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Movies versus TV shows: A count Plot')
plt.show()

# %% [markdown]
# # This clearly shows that movies outnumber TV shows by a large margin

# %%
sns.histplot(x='release_year', data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
top_countries = df['country'].value_counts().head(10)

# %%
top_countries
# Out:
# country
# United States     2818
# India              972
# Unknown            831
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Name: count, dtype: int64

# %%
top_countries = top_countries.reset_index()
top_countries.columns = ['country', 'count']

# %%
sns.barplot(x='country', y='count', data=top_countries)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(x='is_recent', y='duration_minutes', data=df)
plt.xlabel('Is Recent (1 = 2015 or later, 0 = before 2015)')
plt.ylabel('Duration (minutes)')
plt.title('Movie Duration: Recent vs Older Years')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Some Conclusions
# - Median duration is similar for both recent and older movies (nearly ~100 minutes)
# - There are a lot of outliers in both cases, having too long or too short a duration for a movie
# - This suggests that the movie durations have not changed much over time

# %%
df.head()
# Out:
#   show_id     type                  title            director  \
# 0      s1    Movie   Dick Johnson Is Dead     Kirsten Johnson
# 1      s2  TV Show          Blood & Water  No director Listed
# 2      s3  TV Show              Ganglands     Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans  No director Listed
# 4      s5  TV Show           Kota Factory  No director Listed
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                                NaN        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
cols = ['release_year', 'duration_minutes', 'seasons','is_recent']

# %%
num_df = df[cols]

# %% [markdown]
# # Correlation heatmap

# %%
corr = num_df.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
